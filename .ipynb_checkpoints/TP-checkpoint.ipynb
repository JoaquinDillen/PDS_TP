# %% [markdown]
# ## Trabalho Prático
# ### Procesamento Digital de Sinal

# %%
import numpy as np
from scipy.signal import lfilter, lfilter_zi, filtfilt, butter, freqz, welch, spectrogram
from scipy.io.wavfile import read
from matplotlib import pyplot as plt

# %%
filename = 'audio/rec3.wav'
fs, audio1 = read(filename)
f, t, S1 = spectrogram(audio1, fs, window='flattop', nperseg=fs//10, noverlap=fs//20, scaling='spectrum', mode='magnitude')
print('filename: ', filename)
print('Data length (s): ', t[-1])
print('Sampling frequency (samples/s): ', fs)

plt.rcParams['figure.figsize'] = 16,10
plt.pcolormesh(t, f, S1)
plt.xlabel('time(s)')
plt.ylabel('frequency(Hz)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16548/3191316672.py in <module>
#       1 filename = 'audio/rec3.wav'
# ----> 2 fs, audio1 = read(filename)
#       3 f, t, S1 = spectrogram(audio1, fs, window='flattop', nperseg=fs//10, noverlap=fs//20, scaling='spectrum', mode='magnitude')
#       4 print('filename: ', filename)
#       5 print('Data length (s): ', t[-1])
#
# ~\anaconda3\envs\PDS\lib\site-packages\scipy\io\wavfile.py in read(filename, mmap)
#     648
#     649     try:
# --> 650         file_size, is_big_endian = _read_riff_chunk(fid)
#     651         fmt_chunk_received = False
#     652         data_chunk_received = False
#
# ~\anaconda3\envs\PDS\lib\site-packages\scipy\io\wavfile.py in _read_riff_chunk(fid)
#     519     else:
#     520         # There are also .wav files with "FFIR" or "XFIR" signatures?
# ...

# %%
wn = 1000 / (fs/2)
b3,a3 = butter(4, wn)
audio1_filt = lfilter(b3, a3, audio1)

# %%
f, t, S1 = spectrogram(audio1_filt, fs, window='flattop', nperseg=fs//10, noverlap=fs//20, scaling='density', mode='magnitude')
print('filename: ', filename)
print('Data length (s): ', t[-1])
print('Sampling frequency (samples/s): ', fs)

plt.rcParams['figure.figsize'] = 16,10
# pyplot.pcolormesh(t, f[:450], S1[:450][:])
plt.pcolormesh(t, f, S1)
plt.xlabel('time(s)')
plt.ylabel('frequency(Hz)')
plt.show()
# Out:
# filename:  OAF_calm_happy.wav
# Data length (s):  1.9504587531744082
# Sampling frequency (samples/s):  24414
# C:\Users\lemos\AppData\Local\Temp/ipykernel_4072/2224025478.py:8: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolormesh(t, f, S1)

# %%
pyplot.rcParams['figure.figsize'] = 16,5
plot(audio1_filt**2)

# %%
result = [True if item > 0.01*1e8 else False for item in audio1_filt**2]
plot(result)
